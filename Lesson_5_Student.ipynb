# %% [markdown]
# # Lesson 5: Human in the Loop

# %% [markdown]
# Note: This notebook is running in a later version of langgraph that it was filmed with. The later version has a couple of key additions:
# - Additional state information is stored to memory and displayed when using `get_state()` or `get_state_history()`.
# - State is additionally stored every state transition while previously it was stored at an interrupt or at the end.
# These change the command output slightly, but are a useful addtion to the information available.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, ToolMessage
from langchain_openai import ChatOpenAI
from langchain_community.tools.tavily_search import TavilySearchResults
from langgraph.checkpoint.sqlite import SqliteSaver
import sqlite3

# Create a connection manually to keep it alive across notebook cells
conn = sqlite3.connect(":memory:", check_same_thread=False)
memory = SqliteSaver(conn)

# %%
from uuid import uuid4
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage

"""
In previous examples we've annotated the `messages` state key
with the default `operator.add` or `+` reducer, which always
appends new messages to the end of the existing messages array.

Now, to support replacing existing messages, we annotate the
`messages` key with a customer reducer function, which replaces
messages with the same `id`, and appends them otherwise.
"""
def reduce_messages(left: list[AnyMessage], right: list[AnyMessage]) -> list[AnyMessage]:
    # assign ids to messages that don't have them
    for message in right:
        if not message.id:
            message.id = str(uuid4())
    # merge the new messages with the existing messages
    merged = left.copy()
    for message in right:
        for i, existing in enumerate(merged):
            # replace any existing messages with the same id
            if existing.id == message.id:
                merged[i] = message
                break
        else:
            # append any new messages to the end
            merged.append(message)
    return merged

class AgentState(TypedDict):
    messages: Annotated[list[AnyMessage], reduce_messages]

# %%
tool = TavilySearchResults(max_results=2)
# Out:
# C:\Users\mobat\AppData\Local\Temp\ipykernel_7740\4289725543.py:1: LangChainDeprecationWarning: The class `TavilySearchResults` was deprecated in LangChain 0.3.25 and will be removed in 1.0. An updated version of the class exists in the `langchain-tavily package and should be used instead. To use it run `pip install -U `langchain-tavily` and import as `from `langchain_tavily import TavilySearch``.
#   tool = TavilySearchResults(max_results=2)

# %% [markdown]
# ## Manual human approval

# %%
class Agent:
    def __init__(self, model, tools, system="", checkpointer=None):
        self.system = system
        graph = StateGraph(AgentState)
        graph.add_node("llm", self.call_openai)
        graph.add_node("action", self.take_action)
        graph.add_conditional_edges("llm", self.exists_action, {True: "action", False: END})
        graph.add_edge("action", "llm")
        graph.set_entry_point("llm")
        self.graph = graph.compile(
            checkpointer=checkpointer,
            interrupt_before=["action"]
        )
        self.tools = {t.name: t for t in tools}
        self.model = model.bind_tools(tools)

    def call_openai(self, state: AgentState):
        messages = state['messages']
        if self.system:
            messages = [SystemMessage(content=self.system)] + messages
        message = self.model.invoke(messages)
        return {'messages': [message]}

    def exists_action(self, state: AgentState):
        print(state)
        result = state['messages'][-1]
        return len(result.tool_calls) > 0

    def take_action(self, state: AgentState):
        tool_calls = state['messages'][-1].tool_calls
        results = []
        for t in tool_calls:
            print(f"Calling: {t}")
            result = self.tools[t['name']].invoke(t['args'])
            results.append(ToolMessage(tool_call_id=t['id'], name=t['name'], content=str(result)))
        print("Back to the model!")
        return {'messages': results}

# %%
prompt = """You are a smart research assistant. Use the search engine to look up information. \
You are allowed to make multiple calls (either together or in sequence). \
Only look up information when you are sure of what you want. \
If you need to look up some information before asking a follow up question, you are allowed to do that!
"""
model = ChatOpenAI(model="gpt-3.5-turbo")
abot = Agent(model, [tool], system=prompt, checkpointer=memory)

# %%
messages = [HumanMessage(content="Whats the weather in SF?")]
thread = {"configurable": {"thread_id": "1"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='876d741e-3f5d-4824-aa2f-a8097bbdad6f'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JQoIe7NW6wIUEpnIdQ4QaEkOl1S', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea7-4971-7ed0-84b4-17c0e00e8fd3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_WlyKWxbCOpkxbx3joe6LDAjw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JQoIe7NW6wIUEpnIdQ4QaEkOl1S', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea7-4971-7ed0-84b4-17c0e00e8fd3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_WlyKWxbCOpkxbx3joe6LDAjw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='876d741e-3f5d-4824-aa2f-a8097bbdad6f'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JQoIe7NW6wIUEpnIdQ4QaEkOl1S', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea7-4971-7ed0-84b4-17c0e00e8fd3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_WlyKWxbCOpkxbx3joe6LDAjw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67b7-c288-606c-8001-2d6ead7a7632'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T03:44:27.292478+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67b7-a260-61de-8000-0f479424b03f'}}, tasks=(PregelTask(id='499bf56b-7ee8-4c06-df34-4da3d65ddc74', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
abot.graph.get_state(thread).next
# Out:
# ('action',)

# %% [markdown]
# ### continue after interrupt

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_WlyKWxbCOpkxbx3joe6LDAjw', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content="[{'title': 'San Francisco January 2026 Historical Weather Data (California ...', 'url': 'https://weatherspark.com/h/m/557/2026/1/Historical-Weather-in-January-2026-in-San-Francisco-California-United-States', 'content': '| Today  Yesterday  Jan  2026  ---   194019501960197019801990200020102020   ---   2017201820192020202120222023202420252026   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec   ---   12345678910111213141516171819202122232425262728293031 January 2026 Weather History in San Francisco California, United States The data for this report comes from the San Francisco International Airport. See all nearby weather stations  Latest Report — 11:56 AM Mon, Jan 19, 2026    1 hr, 2 min ago    UTC 19:56  Call Sign KSFO  Temp.  55.0°F cool   |  |  |  --- | | Dew Pt. | 48.9°F  dry | | Rel. Humidity | 80% |  Precipitation  No Report  Wind  4.6 mph light breeze   |  |  |  --- | | Wind Dir. | 60 deg, ENE |  Cloud Cover  Partly Cloudy   25,000 ft   |  |  |  --- | | Vis. | 10.00 mi or greater [...] Francisco Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Humidity Comfort Levels in January 2026 in San Francisco18152229112233445566778899101011111212131314141515161617171818191912 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNow  dry   55°F   comfortable   60°F   humid   65°F   muggy   70°F   oppressive   75°F   miserable  The hourly reported humidity comfort level, categorized by dew point. The shaded overlays indicate night and civil twilight.  Wind Speed in January 2026 in San Francisco Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Wind Speed in January 2026 in San Francisco1815222911223344556677889910101111121213131414151516161717181819190 mph0 mph10 mph10 mph20 [...] 25,000 ft   |  |  |  --- | | Vis. | 10.00 mi or greater | | Alt. | 30.11 inHg |  Raw: KSFO 191956Z 06004KT 10SM SCT250 13/09 A3011 RMK AO2 SLP195 T01280094 $  This report shows the past weather for San Francisco, providing a weather history for January 2026. It features all historical weather data series we have available, including the San Francisco temperature history for January 2026. You can drill down from year to month and even day level reports by clicking on the graphs.  San Francisco Temperature History January 2026 Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Temperature history in January 2026 in San', 'score': 0.99972624}, {'title': 'San Francisco weather in January 2026 | Weather25.com', 'url': 'https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=January', 'content': 'The average weather in San Francisco in January\\n\\nThe temperatures in San Francisco in January are quite cold with temperatures between 7°C and 15°C, warm clothes are a must.\\n\\nYou can expect about 3 to 8 days of rain in San Francisco during the month of January. It’s a good idea to bring along your umbrella so that you don’t get caught in poor weather.\\n\\nOur weather forecast can give you a great sense of what weather to expect in San Francisco in January 2026.\\n\\nIf you’re planning to visit San Francisco in the near future, we highly recommend that you review the 14 day weather forecast for San Francisco before you arrive.\\n\\nImage 22: Temperatures\\n\\nTemperatures\\n\\n15° /7° \\n\\nImage 23: Rainy Days\\n\\nRainy Days\\n\\n4\\n\\nImage 24: Snowy Days\\n\\nSnowy Days\\n\\n0\\n\\nImage 25: Dry Days\\n\\nDry Days\\n\\n27 [...] Click on a day for an hourly weather forecast\\n\\nMonday Jan 19 Image 8: Sunny 0 mm 18°/8°Tuesday Jan 20 Image 9: Overcast 0 mm 14°/7°Wednesday Jan 21 Image 10: Overcast 0 mm 12°/11°Thursday Jan 22 Image 11: Fog 0 mm 16°/10°Friday Jan 23 Image 12: Sunny 0 mm 17°/9°Saturday Jan 24 Image 13: Partly cloudy 0 mm 16°/10°Sunday Jan 25 Image 14: Sunny 0 mm 16°/9°Monday Jan 26 Image 15: Sunny 0 mm 15°/10°Tuesday Jan  ...
# {'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='876d741e-3f5d-4824-aa2f-a8097bbdad6f'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JQoIe7NW6wIUEpnIdQ4QaEkOl1S', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea7-4971-7ed0-84b4-17c0e00e8fd3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_WlyKWxbCOpkxbx3joe6LDAjw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="[{'title': 'San Francisco January 2026 Historical Weather Data (California ...', 'url': 'https://weatherspark.com/h/m/557/2026/1/Historical-Weather-in-January-2026-in-San-Francisco-California-United-States', 'content': '| Today  Yesterday  Jan  2026  ---   194019501960197019801990200020102020   ---   2017201820192020202120222023202420252026   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec   ---   12345678910111213141516171819202122232425262728293031 January 2026 Weather History in San Francisco California, United States The data for this report comes from the San Francisco International Airport. See all nearby weather stations  Latest Report — 11:56 AM Mon, Jan 19, 2026    1 hr, 2 min ago    UTC 19:56  Call Sign KSFO  Temp.  55.0°F cool   |  |  |  --- | | Dew Pt. | 48.9°F  dry | | Rel. Humidity | 80% |  Precipitation  No Report  Wind  4.6 mph light breeze   |  |  |  --- | | Wind Dir. | 60 deg, ENE |  Cloud Cover  Partly Cloudy   25,000 ft   |  |  |  --- | | Vis. | 10.00 mi or greater [...] Francisco Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Humidity Comfort Levels in January 2026 in San Francisco18152229112233445566778899101011111212131314141515161617171818191912 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNow  dry   55°F   comfortable   60°F   humid   65°F   muggy   70°F   oppressive   75°F   miserable  The hourly reported humidity comfort level, categorized by dew point. The shaded overlays indicate night and civil twilight.  Wind Speed in January 2026 in San Francisco Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Wind Speed in January 2026 in San Francisco1815222911223344556677889910101111121213131414151516161717181819190 mph0 mph10 mph10 mph20 [...] 25,000 ft   |  |  |  --- | | Vis. | 10.00 mi or greater | | Alt. | 30.11 inHg |  Raw: KSFO 191956Z 06004KT 10SM SCT250 13/09 A3011 RMK AO2 SLP195 T01280094 $  This report shows the past weather for San Francisco, providing a weather history for January 2026. It features all historical weather data series we have available, including the San Francisco temperature history for January 2026. You can drill down from year to month and even day level reports by clicking on the graphs.  San Francisco Temperature History January 2026 Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Temperature history in January 2026 in San', 'score': 0.99972624}, {'title': 'San Francisco weather in January 2026 | Weather25.com', 'url': 'https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=January', 'content': 'The average weather in San Francisco in January\\n\\nThe temperatures in San Francisco in January are quite cold with t ...
# {'messages': [AIMessage(content='The current weather in San Francisco is 55.0°F with a light breeze of 4.6 mph coming from the east-northeast direction. The humidity is at 80% and the sky is partly cloudy with cloud cover at 25,000 ft.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 55, 'prompt_tokens': 1818, 'total_tokens': 1873, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JRZUm8NlI7FuqjcSVWWvrBTQg3z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bdea8-068a-7753-8dbc-755948bdacc4-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1818, 'output_tokens': 55, 'total_tokens': 1873, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in SF?', additional_kwargs={}, response_metadata={}, id='876d741e-3f5d-4824-aa2f-a8097bbdad6f'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JQoIe7NW6wIUEpnIdQ4QaEkOl1S', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea7-4971-7ed0-84b4-17c0e00e8fd3-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in San Francisco'}, 'id': 'call_WlyKWxbCOpkxbx3joe6LDAjw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="[{'title': 'San Francisco January 2026 Historical Weather Data (California ...', 'url': 'https://weatherspark.com/h/m/557/2026/1/Historical-Weather-in-January-2026-in-San-Francisco-California-United-States', 'content': '| Today  Yesterday  Jan  2026  ---   194019501960197019801990200020102020   ---   2017201820192020202120222023202420252026   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec   ---   12345678910111213141516171819202122232425262728293031 January 2026 Weather History in San Francisco California, United States The data for this report comes from the San Francisco International Airport. See all nearby weather stations  Latest Report — 11:56 AM Mon, Jan 19, 2026    1 hr, 2 min ago    UTC 19:56  Call Sign KSFO  Temp.  55.0°F cool   |  |  |  --- | | Dew Pt. | 48.9°F  dry | | Rel. Humidity | 80% |  Precipitation  No Report  Wind  4.6 mph light breeze   |  |  |  --- | | Wind Dir. | 60 deg, ENE |  Cloud Cover  Partly Cloudy   25,000 ft   |  |  |  --- | | Vis. | 10.00 mi or greater [...] Francisco Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Humidity Comfort Levels in January 2026 in San Francisco18152229112233445566778899101011111212131314141515161617171818191912 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNow  dry   55°F   comfortable   60°F   humid   65°F   muggy   70°F   oppressive   75°F   miserable  The hourly reported humidity comfort level, categorized by dew point. The shaded overlays indicate night and civil twilight.  Wind Speed in January 2026 in San Francisco Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Wind Speed in January 2026 in San Francisco1815222911223344556677889910101111121213131414151516161717181819190 mph0 mph10 mph10 mph20 [...] 25,000 ft   |  |  |  --- | | Vis. | 10.00 mi or greater | | Alt. | 30.11 inHg |  Raw: KSFO 191956Z 06004KT 10SM SCT250 13/09 A3011 RMK AO2 SLP195 T01280094 $  This report shows the past weather for San Francisco, providing a weather history for January 2026. It features all historical weather data series we have available, including the San Francisco temperature history for January 2026. You can drill down from year to month and even day level reports by clicking on the graphs.  San Francisco Temperature History January 2026 Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Temperature history in January 2026 in San', 'score': 0.99972624}, {'title': 'San Francisco weather in January 2026 | Weather25.com', 'url': 'https://www.weather25.com/north-america/usa/california/san-francisco?page=month&month=January', 'content': 'The average weather in San Francisco in January\\n\\nThe temperatures in San Francisco in January  ...

# %%
abot.graph.get_state(thread).next
# Out:
# ()

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "2"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
while abot.graph.get_state(thread).next:
    print("\n", abot.graph.get_state(thread),"\n")
    _input = input("proceed?")
    if _input != "y":
        print("aborting")
        break
    for event in abot.graph.stream(None, thread):
        for v in event.values():
            print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='89ba2aa3-edd0-4fb7-813d-63fb78648b8c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JRlaBV0R3nsAmnnAfai3ImFEoUh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-36bb-70c0-91fa-b44142abbb69-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_eCyaV2fykU3RZHtI4LWIFpkw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JRlaBV0R3nsAmnnAfai3ImFEoUh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-36bb-70c0-91fa-b44142abbb69-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_eCyaV2fykU3RZHtI4LWIFpkw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()
#
#  StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='89ba2aa3-edd0-4fb7-813d-63fb78648b8c'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JRlaBV0R3nsAmnnAfai3ImFEoUh', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-36bb-70c0-91fa-b44142abbb69-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_eCyaV2fykU3RZHtI4LWIFpkw', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67b9-f518-69f5-8001-38d52e058914'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T03:45:26.281675+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67b9-e5b1-6558-8000-540cbb06e670'}}, tasks=(PregelTask(id='898cddf4-f531-4c5a-740a-5b608f1510cc', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())
#
# aborting

# %% [markdown]
# ## Modify State
# Run until the interrupt and then modify the state.

# %%
messages = [HumanMessage("Whats the weather in LA?")]
thread = {"configurable": {"thread_id": "3"}}
for event in abot.graph.stream({"messages": messages}, thread):
    for v in event.values():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# ()

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b89c-67be-8001-52f2a8664cb3'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T03:46:13.626463+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b435-6609-8000-bf054e6c72de'}}, tasks=(PregelTask(id='3a79d1fd-cf76-d594-d92e-024b0103ca53', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
current_values = abot.graph.get_state(thread)

# %%
current_values.values['messages'][-1]
# Out:
# AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})

# %%
current_values.values['messages'][-1].tool_calls
# Out:
# [{'name': 'tavily_search_results_json',
#   'args': {'query': 'weather in Los Angeles'},
#   'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7',
#   'type': 'tool_call'}]

# %%
_id = current_values.values['messages'][-1].tool_calls[0]['id']
current_values.values['messages'][-1].tool_calls = [
    {'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in Louisiana'},
  'id': _id}
]

# %%
abot.graph.update_state(thread, current_values.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'configurable': {'thread_id': '3',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0f67bc-b179-6b9b-8002-453cc608e9b3'}}

# %%
abot.graph.get_state(thread)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bc-b179-6b9b-8002-453cc608e9b3'}}, metadata={'source': 'update', 'step': 2, 'parents': {}}, created_at='2026-01-21T03:46:39.721769+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b89c-67be-8001-52f2a8664cb3'}}, tasks=(PregelTask(id='df903942-23ad-0c16-042c-b61a3999ad18', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
for event in abot.graph.stream(None, thread):
    for v in event.values():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content="[{'title': 'Baton Rouge January 2026 Historical Weather Data (Louisiana ...', 'url': 'https://deploy.weatherspark.com/h/m/11336/2026/1/Historical-Weather-in-January-2026-in-Baton-Rouge-Louisiana-United-States', 'content': '| Today  Yesterday  Jan  2026  ---   194019501960197019801990200020102020   ---   2017201820192020202120222023202420252026   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec   ---   12345678910111213141516171819202122232425262728293031 January 2026 Weather History in Baton Rouge Louisiana, United States The data for this report comes from the Baton Rouge Metropolitan Airport. See all nearby weather stations  Latest Report — 8:53 PM Wed, Jan 21, 2026    54 min ago    UTC 02:53  Call Sign KBTR  Temp.  48.9°F cold   |  |  |  --- | | Dew Pt. | 37.9°F  dry | | Rel. Humidity | 66% |  Precipitation  No Report  Wind  6.9 mph light breeze   |  |  |  --- | | Wind Dir. | 110 deg, ESE |  Cloud Cover  Clear   |  |  |  --- | | Vis. | 10.00 mi or greater | | Alt. | 30.36 inHg |  Raw: [...] The daily range of reported temperatures (gray bars) and 24-hour highs (red ticks) and lows (blue ticks), placed over the daily average high (faint red line) and low (faint blue line) temperature, with 25th to 75th and 10th to 90th percentile bands.    Hourly Temperature in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Hourly Temperature in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNowcoolwarmcold  frigid   15°F   freezing   32°F   very cold   45°F   cold   55°F   cool   65°F   comfortable   75°F   warm   85°F   hot   95°F   sweltering  The hourly reported temperature, color [...] 95°F   sweltering  The hourly reported temperature, color coded into bands. The shaded overlays indicate night and civil twilight.  Map Marker   © OpenStreetMap contributors  Compare Baton Rouge to another city: Compare Map    Cloud Cover in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Cloud Cover in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNow  0%   clear   20%   mostly clear   40%   partly cloudy   60%   mostly cloudy   80%   overcast   100%  no significant cloudno cloud detectedceiling and visibility ok  The hourly reported cloud coverage, categorized by the percentage of', 'score': 0.99982053}, {'title': 'Weather Planner: Wednesday, January 21, 2026', 'url': 'https://flxweather.com/2026/01/20/weather-planner-wednesday-january-21-2026/', 'content': '# Weather Planner: Wednesday, January 21, 2026\\n\\nfinger lakes weather forecast wednesday january 21 2026 clouds overtake blue sky above a lightly snow covered field surrounded by forest.\\n\\n## Wednesday, January 21, 2026\\n\\nA weakening weather system will move into the area Wednesday with some snow showers, mainly in the late afternoon.\\n\\n### Early Morning (3-7 AM)\\n\\nMostly clear skies.\\n\\nNo precipitation.\\n\\nWinds SW around 10 mph.\\n\\nTemperatures steady in the upper 0s and low10s with some localized colder pockets possible.\\n\\n### Morning (7-11 AM)\\n\\nEarly sun quickly giving way to cloudy skies.\\n\\nNo precipitation until a few stray flurries late.\\n\\nWinds S around 10 mph.\\n\\nTemperatures rising steadily through the 10s to near 20 degrees.\\n\\n### Midday (11 AM-1 PM)\\n\\nMostly cloudy.\\n\\nA few brief flurries. [...] Mostly cloudy.\\n\\nA few brief flurries.\\n\\nWinds S increasing to 10-15 mph.\\n\\nTemperatures rising into the mid 20s for most areas.\\n\\n### Afternoon (1-4 PM)\\n\\nMostly cloudy.\\n\\nA few brief flurries.\\n\\nWinds S increasing to around 15 mph with a few gusts to 30 mph.\\n\\nTemperatu ...
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="[{'title': 'Baton Rouge January 2026 Historical Weather Data (Louisiana ...', 'url': 'https://deploy.weatherspark.com/h/m/11336/2026/1/Historical-Weather-in-January-2026-in-Baton-Rouge-Louisiana-United-States', 'content': '| Today  Yesterday  Jan  2026  ---   194019501960197019801990200020102020   ---   2017201820192020202120222023202420252026   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec   ---   12345678910111213141516171819202122232425262728293031 January 2026 Weather History in Baton Rouge Louisiana, United States The data for this report comes from the Baton Rouge Metropolitan Airport. See all nearby weather stations  Latest Report — 8:53 PM Wed, Jan 21, 2026    54 min ago    UTC 02:53  Call Sign KBTR  Temp.  48.9°F cold   |  |  |  --- | | Dew Pt. | 37.9°F  dry | | Rel. Humidity | 66% |  Precipitation  No Report  Wind  6.9 mph light breeze   |  |  |  --- | | Wind Dir. | 110 deg, ESE |  Cloud Cover  Clear   |  |  |  --- | | Vis. | 10.00 mi or greater | | Alt. | 30.36 inHg |  Raw: [...] The daily range of reported temperatures (gray bars) and 24-hour highs (red ticks) and lows (blue ticks), placed over the daily average high (faint red line) and low (faint blue line) temperature, with 25th to 75th and 10th to 90th percentile bands.    Hourly Temperature in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Hourly Temperature in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNowcoolwarmcold  frigid   15°F   freezing   32°F   very cold   45°F   cold   55°F   cool   65°F   comfortable   75°F   warm   85°F   hot   95°F   sweltering  The hourly reported temperature, color [...] 95°F   sweltering  The hourly reported temperature, color coded into bands. The shaded overlays indicate night and civil twilight.  Map Marker   © OpenStreetMap contributors  Compare Baton Rouge to another city: Compare Map    Cloud Cover in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Cloud Cover in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNow  0%   clear   20%   mostly clear   40%   partly cloudy   60%   mostly cloudy   80%   overcast   100%  no significant cloudno cloud detectedceiling and visibility ok  The hourly reported cloud coverage, categorized by the percentage of', 'score': 0.99982053}, {'title': 'Weather Planner: Wednesday, January 21, 2026', 'url': 'https://flxweather.com/2026/01/20/weather-planner-wednesday-january-21-2026/', 'content': '# Weather  ...
# {'messages': [AIMessage(content='I found information on the current weather in Baton Rouge, Louisiana. The temperature is 48.9°F with clear skies and a light breeze of 6.9 mph coming from the east-southeast. The humidity is at 66%.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 50, 'prompt_tokens': 1726, 'total_tokens': 1776, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JTCUddkdtrfMsJBPhlpNaVM6Epo', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bdea9-9474-75b2-8b45-b89a0156a601-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1726, 'output_tokens': 50, 'total_tokens': 1776, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Time Travel

# %%
states = []
for state in abot.graph.get_state_history(thread):
    print(state)
    print('--')
    states.append(state)
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="[{'title': 'Baton Rouge January 2026 Historical Weather Data (Louisiana ...', 'url': 'https://deploy.weatherspark.com/h/m/11336/2026/1/Historical-Weather-in-January-2026-in-Baton-Rouge-Louisiana-United-States', 'content': '| Today  Yesterday  Jan  2026  ---   194019501960197019801990200020102020   ---   2017201820192020202120222023202420252026   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec   ---   12345678910111213141516171819202122232425262728293031 January 2026 Weather History in Baton Rouge Louisiana, United States The data for this report comes from the Baton Rouge Metropolitan Airport. See all nearby weather stations  Latest Report — 8:53 PM Wed, Jan 21, 2026    54 min ago    UTC 02:53  Call Sign KBTR  Temp.  48.9°F cold   |  |  |  --- | | Dew Pt. | 37.9°F  dry | | Rel. Humidity | 66% |  Precipitation  No Report  Wind  6.9 mph light breeze   |  |  |  --- | | Wind Dir. | 110 deg, ESE |  Cloud Cover  Clear   |  |  |  --- | | Vis. | 10.00 mi or greater | | Alt. | 30.36 inHg |  Raw: [...] The daily range of reported temperatures (gray bars) and 24-hour highs (red ticks) and lows (blue ticks), placed over the daily average high (faint red line) and low (faint blue line) temperature, with 25th to 75th and 10th to 90th percentile bands.    Hourly Temperature in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Hourly Temperature in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNowcoolwarmcold  frigid   15°F   freezing   32°F   very cold   45°F   cold   55°F   cool   65°F   comfortable   75°F   warm   85°F   hot   95°F   sweltering  The hourly reported temperature, color [...] 95°F   sweltering  The hourly reported temperature, color coded into bands. The shaded overlays indicate night and civil twilight.  Map Marker   © OpenStreetMap contributors  Compare Baton Rouge to another city: Compare Map    Cloud Cover in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Cloud Cover in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNow  0%   clear   20%   mostly clear   40%   partly cloudy   60%   mostly cloudy   80%   overcast   100%  no significant cloudno cloud detectedceiling and visibility ok  The hourly reported cloud coverage, categorized by the percentage of', 'score': 0.99982053}, {'title': 'Weather Planner: Wednesday, January 21, 2026', 'url': 'https://flxweather.com/2026/01/20/weather-planner-wednesday-january-21-2026/', ' ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content="[{'title': 'Baton Rouge January 2026 Historical Weather Data (Louisiana ...', 'url': 'https://deploy.weatherspark.com/h/m/11336/2026/1/Historical-Weather-in-January-2026-in-Baton-Rouge-Louisiana-United-States', 'content': '| Today  Yesterday  Jan  2026  ---   194019501960197019801990200020102020   ---   2017201820192020202120222023202420252026   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec   ---   12345678910111213141516171819202122232425262728293031 January 2026 Weather History in Baton Rouge Louisiana, United States The data for this report comes from the Baton Rouge Metropolitan Airport. See all nearby weather stations  Latest Report — 8:53 PM Wed, Jan 21, 2026    54 min ago    UTC 02:53  Call Sign KBTR  Temp.  48.9°F cold   |  |  |  --- | | Dew Pt. | 37.9°F  dry | | Rel. Humidity | 66% |  Precipitation  No Report  Wind  6.9 mph light breeze   |  |  |  --- | | Wind Dir. | 110 deg, ESE |  Cloud Cover  Clear   |  |  |  --- | | Vis. | 10.00 mi or greater | | Alt. | 30.36 inHg |  Raw: [...] The daily range of reported temperatures (gray bars) and 24-hour highs (red ticks) and lows (blue ticks), placed over the daily average high (faint red line) and low (faint blue line) temperature, with 25th to 75th and 10th to 90th percentile bands.    Hourly Temperature in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Hourly Temperature in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNowcoolwarmcold  frigid   15°F   freezing   32°F   very cold   45°F   cold   55°F   cool   65°F   comfortable   75°F   warm   85°F   hot   95°F   sweltering  The hourly reported temperature, color [...] 95°F   sweltering  The hourly reported temperature, color coded into bands. The shaded overlays indicate night and civil twilight.  Map Marker   © OpenStreetMap contributors  Compare Baton Rouge to another city: Compare Map    Cloud Cover in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Cloud Cover in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNow  0%   clear   20%   mostly clear   40%   partly cloudy   60%   mostly cloudy   80%   overcast   100%  no significant cloudno cloud detectedceiling and visibility ok  The hourly reported cloud coverage, categorized by the percentage of', 'score': 0.99982053}, {'title': 'Weather Planner: Wednesday, January 21, 2026', 'url': 'https://flxweather.com/2026/01/20/weather-planner-wednesday-january-21-2026/', ' ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in Louisiana'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bc-b179-6b9b-8002-453cc608e9b3'}}, metadata={'source': 'update', 'step': 2, 'parents': {}}, created_at='2026-01-21T03:46:39.721769+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b89c-67be-8001-52f2a8664cb3'}}, tasks=(PregelTask(id='df903942-23ad-0c16-042c-b61a3999ad18', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result={'messages': [ToolMessage(content="[{'title': 'Baton Rouge January 2026 Historical Weather Data (Louisiana ...', 'url': 'https://deploy.weatherspark.com/h/m/11336/2026/1/Historical-Weather-in-January-2026-in-Baton-Rouge-Louisiana-United-States', 'content': '| Today  Yesterday  Jan  2026  ---   194019501960197019801990200020102020   ---   2017201820192020202120222023202420252026   ---   SpringSummerFallWinter  JanFebMarAprMayJunJulAugSepOctNovDec   ---   12345678910111213141516171819202122232425262728293031 January 2026 Weather History in Baton Rouge Louisiana, United States The data for this report comes from the Baton Rouge Metropolitan Airport. See all nearby weather stations  Latest Report — 8:53 PM Wed, Jan 21, 2026    54 min ago    UTC 02:53  Call Sign KBTR  Temp.  48.9°F cold   |  |  |  --- | | Dew Pt. | 37.9°F  dry | | Rel. Humidity | 66% |  Precipitation  No Report  Wind  6.9 mph light breeze   |  |  |  --- | | Wind Dir. | 110 deg, ESE |  Cloud Cover  Clear   |  |  |  --- | | Vis. | 10.00 mi or greater | | Alt. | 30.36 inHg |  Raw: [...] The daily range of reported temperatures (gray bars) and 24-hour highs (red ticks) and lows (blue ticks), placed over the daily average high (faint red line) and low (faint blue line) temperature, with 25th to 75th and 10th to 90th percentile bands.    Hourly Temperature in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Hourly Temperature in January 2026 in Baton Rouge181522291122334455667788991010111112121313141415151616171718181919202012 AM12 AM3 AM3 AM6 AM6 AM9 AM9 AM12 PM12 PM3 PM3 PM6 PM6 PM9 PM9 PM12 AM12 AMDecFebNowNowcoolwarmcold  frigid   15°F   freezing   32°F   very cold   45°F   cold   55°F   cool   65°F   comfortable   75°F   warm   85°F   hot   95°F   sweltering  The hourly reported temperature, color [...] 95°F   sweltering  The hourly reported temperature, color coded into bands. The shaded overlays indicate night and civil twilight.  Map Marker   © OpenStreetMap contributors  Compare Baton Rouge to another city: Compare Map    Cloud Cover in January 2026 in Baton Rouge Winter 2026  Link  Download  Compare  Averages  History:JanFMAMJJASOND2025202420232022  Cloud Cover in January 2026 in Baton Rouge1815222911223344556 ...
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b89c-67be-8001-52f2a8664cb3'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T03:46:13.626463+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b435-6609-8000-bf054e6c72de'}}, tasks=(PregelTask(id='3a79d1fd-cf76-d594-d92e-024b0103ca53', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())
# --
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405')]}, next=('llm',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b435-6609-8000-bf054e6c72de'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-21T03:46:13.164800+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b42f-6a1d-bfff-e0ac1e32a399'}}, tasks=(PregelTask(id='45aed984-ddb1-71b5-dd16-58045af343f8', name='llm', path=('__pregel_pull', 'llm'), error=None, interrupts=(), state=None, result={'messages': [AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}),), interrupts=())
# --
# StateSnapshot(values={'messages': []}, next=('__start__',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b42f-6a1d-bfff-e0ac1e32a399'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-21T03:46:13.162447+00:00', parent_config=None, tasks=(PregelTask(id='cb8e7e48-5a94-e172-c40f-786c610cb668', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={})]}),), interrupts=())
# --

# %% [markdown]
# To fetch the same state as was filmed, the offset below is changed to `-3` from `-1`. This accounts for the initial state `__start__` and the first state that are now stored to state memory with the latest version of software.

# %%
to_replay = states[-3]

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b89c-67be-8001-52f2a8664cb3'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T03:46:13.626463+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b435-6609-8000-bf054e6c72de'}}, tasks=(PregelTask(id='3a79d1fd-cf76-d594-d92e-024b0103ca53', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
for event in abot.graph.stream(None, to_replay.config):
    for k, v in event.items():
        print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'title\': \'Los Angeles weather in January 2026 | Weather25.com\', \'url\': \'https://www.weather25.com/north-america/usa/california/los-angeles?page=month&month=January\', \'content\': \'The average weather in Los Angeles in January\\n\\nThe temperatures in Los Angeles in January are comfortable with low of 11°C and and high up to 21°C.\\n\\nYou can expect about 3 to 8 days of rain in Los Angeles during the month of January. It’s a good idea to bring along your umbrella so that you don’t get caught in poor weather.\\n\\nOur weather forecast can give you a great sense of what weather to expect in Los Angeles in January 2026.\\n\\nIf you’re planning to visit Los Angeles in the near future, we highly recommend that you review the 14 day weather forecast for Los Angeles before you arrive.\\n\\nImage 22: Temperatures\\n\\nTemperatures\\n\\n21° /11° \\n\\nImage 23: Rainy Days\\n\\nRainy Days\\n\\n3\\n\\nImage 24: Snowy Days\\n\\nSnowy Days\\n\\n0\\n\\nImage 25: Dry Days\\n\\nDry Days\\n\\n28\\n\\nImage 26: Rainfall\\n\\nRainfall\\n\\n58\\n\\nmm [...] Los Angeles weather in January 2026 | Weather25.com\\n\\nImage 1: weather25.com\\n\\nUnited StatesEnglandAustraliaCanada\\n\\n°F- [x]  °C\\n\\nImage 2: Search \\n\\n Los Angeles Image 3: weather in United States\\n\\nWeather in January 2026 \\n\\n   Overview\\n   14 Days\\n   January\\n   February\\n   Long range\\n   Today\\n   Tomorrow\\n\\nImage 4: Remove from your favorite locationsImage 5: Add to my locations\\n\\nImage 6: Share\\n\\n1.   Home\\n2.    North America\\n3.    Image 7: weather in United StatesUnited States\\n4.    California\\n5.    Los Angeles\\n6.    January\\n\\nLocation was added to My Locations\\n\\nLocation was removed from My Locations\\n\\nDecemberFebruary\\n\\nLos Angeles weather in January 2026\\n\\n Click on a day for an hourly weather forecast [...] Hotels in Los Angeles\\n\\nImage 59: 5 stars hotel in Los Angeles Image 60: Hotel starImage 61: Hotel starImage 62: Hotel starImage 63: Hotel starImage 64: Hotel star Pendry West Hollywood Book NowImage 65: 5 stars hotel in Los Angeles Image 66: Hotel starImage 67: Hotel starImage 68: Hotel starImage 69: Hotel starImage 70: Hotel star Waldorf Astoria Beverly Hills Book NowImage 71: 5 stars hotel in Los Angeles Image 72: Hotel starImage 73: Hotel starImage 74: Hotel starImage 75: Hotel starImage 76: Hotel star Shutters On The Beach Book Now\\n\\nWeather in Los Angeles in January - FAQ\\n\\nWhat is the average temperature in Los Angeles in January?\\n\\nThe average temperature in Los Angeles in January is 11/21° C.\\n\\nWhat is the chance of rain in Los Angeles in January?\', \'score\': 0.9992563}, {\'title\': \'Weather in Los Angeles in January 2026 (California)\', \'url\': \'https://world-weather.info/forecast/usa/los_angeles/january-2026/\', \'content\': "Weather in Los Angeles in January 2026 (California) - Detailed Weather Forecast for a Month\\n\\n, based on January 2026 wind statistics.\\n\\nAverage values in January\\n\\nWind speed\\n\\nmph\\n\\nPressure\\n\\ninHg\\n\\nHumidity\\n\\n%\\n\\nAverage daytime values for January 2026.\\n\\nExtended weather forecast in Los Angeles\\n\\nHourlyWeek10-Day14-Day30-DayYear\\n\\nWeather in large and nearby cities\\n\\nWeather in Washington, D.C.+28°\\n\\nSacramento+48°\\n\\nMarina del Rey+61°\\n\\nMonterey Park+57°\\n\\nNorth Glendale+59°\\n\\nNorwalk+59°\\n\\nPasadena+59°\\n\\nRosemead+59°\\n\\nSanta Monica+59°\\n\\nSouth El Monte+59°\\n\\nManhattan Beach+61°\\n\\nInglewood+59°\\n\\nBellflower+59°\\n\\nBeverly Hills+63°\\n\\nBurbank+59°\\n\\nCompton+59°\\n\\nGlenoaks Canyon+59°\\n\\nBell Canyon+55°\\n\\nMinimum and maximum\\n\\nworld\'s temperature today\\n\\n_Russia_\\n\\nKachug day-38°F night-58°F\\n\\n_Australia_ [...] _Russia_\\n\\nKachug day-38°F night-58°F\\n\\n_Australia_\\n\\nRoebourne day+106°F night+82°F\\n\\nServices\\n\\nSupport\\n\\n   User agreement\\n   Feedback\\n   About Us\\n\\nSearch\\n\\nCity or place… \\n\\n ...
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{\'title\': \'Los Angeles weather in January 2026 | Weather25.com\', \'url\': \'https://www.weather25.com/north-america/usa/california/los-angeles?page=month&month=January\', \'content\': \'The average weather in Los Angeles in January\\n\\nThe temperatures in Los Angeles in January are comfortable with low of 11°C and and high up to 21°C.\\n\\nYou can expect about 3 to 8 days of rain in Los Angeles during the month of January. It’s a good idea to bring along your umbrella so that you don’t get caught in poor weather.\\n\\nOur weather forecast can give you a great sense of what weather to expect in Los Angeles in January 2026.\\n\\nIf you’re planning to visit Los Angeles in the near future, we highly recommend that you review the 14 day weather forecast for Los Angeles before you arrive.\\n\\nImage 22: Temperatures\\n\\nTemperatures\\n\\n21° /11° \\n\\nImage 23: Rainy Days\\n\\nRainy Days\\n\\n3\\n\\nImage 24: Snowy Days\\n\\nSnowy Days\\n\\n0\\n\\nImage 25: Dry Days\\n\\nDry Days\\n\\n28\\n\\nImage 26: Rainfall\\n\\nRainfall\\n\\n58\\n\\nmm [...] Los Angeles weather in January 2026 | Weather25.com\\n\\nImage 1: weather25.com\\n\\nUnited StatesEnglandAustraliaCanada\\n\\n°F- [x]  °C\\n\\nImage 2: Search \\n\\n Los Angeles Image 3: weather in United States\\n\\nWeather in January 2026 \\n\\n   Overview\\n   14 Days\\n   January\\n   February\\n   Long range\\n   Today\\n   Tomorrow\\n\\nImage 4: Remove from your favorite locationsImage 5: Add to my locations\\n\\nImage 6: Share\\n\\n1.   Home\\n2.    North America\\n3.    Image 7: weather in United StatesUnited States\\n4.    California\\n5.    Los Angeles\\n6.    January\\n\\nLocation was added to My Locations\\n\\nLocation was removed from My Locations\\n\\nDecemberFebruary\\n\\nLos Angeles weather in January 2026\\n\\n Click on a day for an hourly weather forecast [...] Hotels in Los Angeles\\n\\nImage 59: 5 stars hotel in Los Angeles Image 60: Hotel starImage 61: Hotel starImage 62: Hotel starImage 63: Hotel starImage 64: Hotel star Pendry West Hollywood Book NowImage 65: 5 stars hotel in Los Angeles Image 66: Hotel starImage 67: Hotel starImage 68: Hotel starImage 69: Hotel starImage 70: Hotel star Waldorf Astoria Beverly Hills Book NowImage 71: 5 stars hotel in Los Angeles Image 72: Hotel starImage 73: Hotel starImage 74: Hotel starImage 75: Hotel starImage 76: Hotel star Shutters On The Beach Book Now\\n\\nWeather in Los Angeles in January - FAQ\\n\\nWhat is the average temperature in Los Angeles in January?\\n\\nThe average temperature in Los Angeles in January is 11/21° C.\\n\\nWhat is the chance of rain in Los Angeles in January?\', \'score\': 0.9992563}, {\'title\': \'Weather in Los Angeles in January 2026 (California)\', \'url\': \'https://world-weather.info/forecast/usa/los_angeles/january-2026/\', \'conten ...
# {'messages': [AIMessage(content="The weather in Los Angeles in January is comfortable with a low of 11°C and a high of up to 21°C. There can be about 3 to 8 days of rain in Los Angeles during January. If you're planning to visit Los Angeles in the near future, it's recommended to review the 14-day weather forecast before you arrive.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 73, 'prompt_tokens': 1425, 'total_tokens': 1498, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JVRHAiZWcxYdroDoFytRqoQEqiU', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bdeab-b003-71b0-87db-5f9f5fbd5aee-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1425, 'output_tokens': 73, 'total_tokens': 1498, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Go back in time and edit

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b89c-67be-8001-52f2a8664cb3'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T03:46:13.626463+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b435-6609-8000-bf054e6c72de'}}, tasks=(PregelTask(id='3a79d1fd-cf76-d594-d92e-024b0103ca53', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']
to_replay.values['messages'][-1].tool_calls = [{'name': 'tavily_search_results_json',
  'args': {'query': 'current weather in LA, accuweather'},
  'id': _id}]

# %%
branch_state = abot.graph.update_state(to_replay.config, to_replay.values)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %%
for event in abot.graph.stream(None, branch_state):
    for k, v in event.items():
        if k != "__end__":
            print(v)
# Out:
# Calling: {'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}
# Back to the model!
# {'messages': [ToolMessage(content='[{\'title\': \'Los Angeles, CA Monthly Weather - AccuWeather\', \'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/january-weather/347625\', \'content\': "# Los Angeles, CA\\n\\nLos Angeles\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## January\\n\\n## 2026\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### February 2026\\n\\n### March 2026\\n\\n### April 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWinter Weather\\n\\nMajor snow, ice storm to affect 150 million across South, East U.S.\\n\\n5 hours ago\\n\\nWinter Weather [...] 5 hours ago\\n\\nWinter Weather\\n\\nSnow buries Russia\'s Kamchatka Peninsula, but don\'t believe the videos\\n\\n7 hours ago\\n\\nWinter Weather\\n\\nMore snow, lake-effect to accumulate in the Midwest, Northeast\\n\\n9 hours ago\\n\\nWinter Weather\\n\\nDangerously cold air to surge through dozens of states later this week\\n\\n8 hours ago\\n\\nWeather News\\n\\nDeadly wildfires burned across southern Chile amid extreme heat and wi...\\n\\n9 hours ago\\n\\nFeatured Stories\\n\\nAstronomy\\n\\nRare purple, blue aurora appeared during Monday night\'s solar storm\\n\\n10 hours ago\\n\\nWinter Weather\\n\\nMassive 100-vehicle crash shuts down highway, multiple injured\\n\\n15 hours ago\\n\\nClimate\\n\\nWestern US faces worsening snow drought, with California the exception\\n\\n4 days ago\\n\\nClimate\\n\\nWhy this famous iceberg turned blue and what it says about melting ice [...] 4 days ago\\n\\nWeather News\\n\\nHigh-speed train crash kills dozens in Spain, many more injured\\n\\n1 day ago\\n\\n## Weather Near Los Angeles:\\n\\n...\\n\\n...\\n\\n...", \'score\': 0.54855317}, {\'title\': \'2026 - West Los Angeles, CA Monthly Weather | AccuWeather\', \'url\': \'https://www.accuweather.com/en/us/west-los-angeles/90025/january-weather/2142540\', \'content\': "5 hours ago\\n\\nWinter Weather\\n\\nSnow buries Russia\'s Kamchatka Peninsula, but don\'t believe the videos\\n\\n7 hours ago\\n\\nWinter Weather\\n\\nMore snow, lake-effect to accumulate in the Midwest, Northeast\\n\\n9 hours ago\\n\\nWinter Weather\\n\\nDangerously cold air to surge through dozens of states later this week\\n\\n8 hours ago\\n\\nWeather News\\n\\nDeadly wildfires burned across southern Chile amid extreme heat and wi...\\n\\n9 hours ago\\n\\nFeatured Stories\\n\\nAstronomy\\n\\nRare purple, blue aurora appeared during Monday night\'s solar storm\\n\\n10 hours ago\\n\\nWinter Weather\\n\\nMassive 100-vehicle crash shuts down highway, multiple injured\\n\\n15 hours ago\\n\\nClimate\\n\\nWestern US faces worsening snow drought, with California the exception\\n\\n4 days ago\\n\\nClimate\\n\\nWhy this famous iceberg turned blue and what it says about melting ice [...] # West Los Angeles, CA\\n\\nWest Los Angeles\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## January\\n\\n## 2026\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### February 2026\\n\\n### March 2026\\n\\n###  ...
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='[{\'title\': \'Los Angeles, CA Monthly Weather - AccuWeather\', \'url\': \'https://www.accuweather.com/en/us/los-angeles/90012/january-weather/347625\', \'content\': "# Los Angeles, CA\\n\\nLos Angeles\\n\\nCalifornia\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News & Features\\n\\n### Astronomy\\n\\n### Business\\n\\n### Climate\\n\\n### Health\\n\\n### Recreation\\n\\n### Sports\\n\\n### Travel\\n\\n### Warnings\\n\\n### Data Suite\\n\\n### Forensics\\n\\n### Advertising\\n\\n### Superior Accuracy™\\n\\n### Video\\n\\n### Winter Center\\n\\n## Monthly\\n\\n## January\\n\\n## 2026\\n\\n## Daily\\n\\n## Temperature Graph\\n\\n## Further Ahead\\n\\nFurther Ahead\\n\\n### February 2026\\n\\n### March 2026\\n\\n### April 2026\\n\\n## Around the Globe\\n\\nAround the Globe\\n\\n### Hurricane Tracker\\n\\n### Severe Weather\\n\\n### Radar & Maps\\n\\n### News\\n\\n### Video\\n\\n### Winter Center\\n\\nTop Stories\\n\\nWinter Weather\\n\\nMajor snow, ice storm to affect 150 million across South, East U.S.\\n\\n5 hours ago\\n\\nWinter Weather [...] 5 hours ago\\n\\nWinter Weather\\n\\nSnow buries Russia\'s Kamchatka Peninsula, but don\'t believe the videos\\n\\n7 hours ago\\n\\nWinter Weather\\n\\nMore snow, lake-effect to accumulate in the Midwest, Northeast\\n\\n9 hours ago\\n\\nWinter Weather\\n\\nDangerously cold air to surge through dozens of states later this week\\n\\n8 hours ago\\n\\nWeather News\\n\\nDeadly wildfires burned across southern Chile amid extreme heat and wi...\\n\\n9 hours ago\\n\\nFeatured Stories\\n\\nAstronomy\\n\\nRare purple, blue aurora appeared during Monday night\'s solar storm\\n\\n10 hours ago\\n\\nWinter Weather\\n\\nMassive 100-vehicle crash shuts down highway, multiple injured\\n\\n15 hours ago\\n\\nClimate\\n\\nWestern US faces worsening snow drought, with California the exception\\n\\n4 days ago\\n\\nClimate\\n\\nWhy this famous iceberg turned blue and what it says about melting ice [...] 4 days ago\\n\\nWeather News\\n\\nHigh-speed train crash kills dozens in Spain, many more injured\\n\\n1 day ago\\n\\n## Weather Near Los Angeles:\\n\\n...\\n\\n...\\n\\n...", \'score\': 0.54855317}, {\'title\': \'2026 - West Los Angeles, CA Monthly Weather | AccuWeather\', \'url\': \'https://www.accuweather.com/en/us/west-los-angeles/90025/january-weather/2142540\', \'content\': "5 hours ago\\n\\nWinter Weather\\n\\nSnow buries Russia\'s Kamchatka Peninsula, but don\'t believe the videos\\n\\n7 hours ago\\n\\nWinter Weather\\n\\nMore snow, lake-effect to accumulate in the Midwest, Northeast\\n\\n9 hours ago\\n\\nWinter Weather\\n\\nDangerously cold air to surge through dozens of states later this week\\n\\n8 hours ago\\n\\nWeather News\\n\\nDeadly wildfires bu ...
# {'messages': [AIMessage(content='I found some information about the current weather in Los Angeles. Would you like me to provide more details from any specific source mentioned in the search results?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 1276, 'total_tokens': 1307, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JYKKcNRxvMbJZHSjfUdWDMSsXhf', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bdeae-6e85-7571-b7de-7d61f47ecd84-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 1276, 'output_tokens': 31, 'total_tokens': 1307, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# ## Add message to a state at a given time

# %%
to_replay
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'current weather in LA, accuweather'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}, next=('action',), config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b89c-67be-8001-52f2a8664cb3'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T03:46:13.626463+00:00', parent_config={'configurable': {'thread_id': '3', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67bb-b435-6609-8000-bf054e6c72de'}}, tasks=(PregelTask(id='3a79d1fd-cf76-d594-d92e-024b0103ca53', name='action', path=('__pregel_pull', 'action'), error=None, interrupts=(), state=None, result=None),), interrupts=())

# %%
_id = to_replay.values['messages'][-1].tool_calls[0]['id']

# %%
state_update = {"messages": [ToolMessage(
    tool_call_id=_id,
    name="tavily_search_results_json",
    content="54 degree celcius",
)]}

# %%
branch_and_add = abot.graph.update_state(
    to_replay.config, 
    state_update, 
    as_node="action")

# %%
for event in abot.graph.stream(None, branch_and_add):
    for k, v in event.items():
        print(v)
# Out:
# {'messages': [HumanMessage(content='Whats the weather in LA?', additional_kwargs={}, response_metadata={}, id='35ff9caa-7f0c-4c6c-a83e-83a32a0c8405'), AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 21, 'prompt_tokens': 152, 'total_tokens': 173, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JSXEcbceEF8KRFiFkc9Hk6gE0on', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019bdea8-f42d-7e93-865b-a9f21b45984f-0', tool_calls=[{'name': 'tavily_search_results_json', 'args': {'query': 'weather in Los Angeles'}, 'id': 'call_v5N9FfFVVrTsyKBH0J8CsSD7', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 152, 'output_tokens': 21, 'total_tokens': 173, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}), ToolMessage(content='54 degree celcius', name='tavily_search_results_json', id='c802aa46-7515-4f92-a2d6-6da16477102f', tool_call_id='call_v5N9FfFVVrTsyKBH0J8CsSD7'), AIMessage(content='The current temperature in Los Angeles is 54 degrees Celsius.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 190, 'total_tokens': 203, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JZ3uSiuQMLteAFdAbYSg1JM3H37', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bdeaf-1bc2-7801-9014-ae37d828de9d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 190, 'output_tokens': 13, 'total_tokens': 203, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}
# {'messages': [AIMessage(content='The current temperature in Los Angeles is 54 degrees Celsius.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 13, 'prompt_tokens': 190, 'total_tokens': 203, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-3.5-turbo-0125', 'system_fingerprint': None, 'id': 'chatcmpl-D0JZ3uSiuQMLteAFdAbYSg1JM3H37', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019bdeaf-1bc2-7801-9014-ae37d828de9d-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 190, 'output_tokens': 13, 'total_tokens': 203, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}})]}

# %% [markdown]
# # Extra Practice

# %% [markdown]
# ## Build a small graph
# This is a small simple graph you can tinker with if you want more insight into controlling state memory.

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated
import operator
from langgraph.checkpoint.sqlite import SqliteSaver

# %% [markdown]
# Define a simple 2 node graph with the following state:
# -`lnode`: last node
# -`scratch`: a scratchpad location
# -`count` : a counter that is incremented each step

# %%
class AgentState(TypedDict):
    lnode: str
    scratch: str
    count: Annotated[int, operator.add]

# %%
def node1(state: AgentState):
    print(f"node1, count:{state['count']}")
    return {"lnode": "node_1",
            "count": 1,
           }
def node2(state: AgentState):
    print(f"node2, count:{state['count']}")
    return {"lnode": "node_2",
            "count": 1,
           }

# %% [markdown]
# The graph goes N1->N2->N1... but breaks after count reaches 3.

# %%
def should_continue(state):
    return state["count"] < 3

# %%
builder = StateGraph(AgentState)
builder.add_node("Node1", node1)
builder.add_node("Node2", node2)

builder.add_edge("Node1", "Node2")
builder.add_conditional_edges("Node2", 
                              should_continue, 
                              {True: "Node1", False: END})
builder.set_entry_point("Node1")

# %%
memory_cm = SqliteSaver.from_conn_string(":memory:")
memory = memory_cm.__enter__()
graph = builder.compile(checkpointer=memory)

# %% [markdown]
# ### Run it!
# Now, set the thread and run!

# %%
thread = {"configurable": {"thread_id": str(1)}}
graph.invoke({"count":0, "scratch":"hi"},thread)

# %%
thread = {"configurable": {"thread_id": str(1)}}
graph.invoke({"count":0, "scratch":"hi"},thread)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# ### Look at current state

# %% [markdown]
# Get the current state. Note the `values` which are the AgentState. Note the `config` and the `thread_ts`. You will be using those to refer to snapshots below.

# %%
graph.get_state(thread)
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa3-630f-8004-3d0e6467770e'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-01-21T04:13:20.075444+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa1-6f55-8003-ea7b31594171'}}, tasks=(), interrupts=())

# %% [markdown]
# View all the statesnapshots in memory. You can use the displayed `count` agentstate variable to help track what you see. Notice the most recent snapshots are returned by the iterator first. Also note that there is a handy `step` variable in the metadata that counts the number of steps in the graph execution. This is a bit detailed - but you can also notice that the *parent_config* is the *config* of the previous node. At initial startup, additional states are inserted into memory to create a parent. This is something to check when you branch or *time travel* below.

# %% [markdown]
# ### Look at state history

# %%
for state in graph.get_state_history(thread):
    print(state, "\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa3-630f-8004-3d0e6467770e'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-01-21T04:13:20.075444+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa1-6f55-8003-ea7b31594171'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa1-6f55-8003-ea7b31594171'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-01-21T04:13:20.074939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9f-6840-8002-9178c3e3e6bb'}}, tasks=(PregelTask(id='f27515d9-7afa-970d-b877-466b0292a670', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9f-6840-8002-9178c3e3e6bb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-21T04:13:20.073939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}}, tasks=(PregelTask(id='e82fda0a-394d-6176-e2af-70dc2850705f', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T04:13:20.071939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a26-8000-1efe343bc4a2'}}, tasks=(PregelTask(id='ae3dd7ce-701d-2b3a-21b7-3cdb6afcb5ee', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a26-8000-1efe343bc4a2'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-21T04:13:20.071939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f95-6bcb-bfff-9cf2ca67628d'}}, tasks=(PregelTask(id='b8fe4744-950f-f6d6-4c34-781456673fab', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f95-6bcb-bfff-9cf2ca67628d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-21T04:13:20.069933+00:00', parent_config=None, tasks=(PregelTask(id='45bd3b51-b2a4-53fe-c6a1-8f311f7ec9f1', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# Store just the `config` into an list. Note the sequence of counts on the right. `get_state_history` returns the most recent snapshots first.

# %%
states = []
for state in graph.get_state_history(thread):
    states.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa3-630f-8004-3d0e6467770e'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa1-6f55-8003-ea7b31594171'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9f-6840-8002-9178c3e3e6bb'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a26-8000-1efe343bc4a2'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f95-6bcb-bfff-9cf2ca67628d'}} 0

# %% [markdown]
# Grab an early state.

# %%
states[-3]
# Out:
# {'configurable': {'thread_id': '1',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}}

# %% [markdown]
# This is the state after Node1 completed for the first time. Note `next` is `Node2`and `count` is 1.

# %%
graph.get_state(states[-3])
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T04:13:20.071939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a26-8000-1efe343bc4a2'}}, tasks=(PregelTask(id='ae3dd7ce-701d-2b3a-21b7-3cdb6afcb5ee', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# ### Go Back in Time
# Use that state in `invoke` to go back in time. Notice it uses states[-3] as *current_state* and continues to node2,

# %%
graph.invoke(None, states[-3])
# Out:
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %% [markdown]
# Notice the new states are now in state history. Notice the counts on the far right.

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-9009-65c2-8004-9353036097db'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-9006-6ebf-8003-e97da7cd6c10'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-8fff-6990-8002-a197dd96fac3'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa3-630f-8004-3d0e6467770e'}} 4
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa1-6f55-8003-ea7b31594171'}} 3
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9f-6840-8002-9178c3e3e6bb'}} 2
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}} 1
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a26-8000-1efe343bc4a2'}} 0
# {'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f95-6bcb-bfff-9cf2ca67628d'}} 0

# %% [markdown]
# You can see the details below. Lots of text, but try to find the node that start the new branch. Notice the parent *config* is not the previous entry in the stack, but is the entry from state[-3].

# %%
thread = {"configurable": {"thread_id": str(1)}}
for state in graph.get_state_history(thread):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-9009-65c2-8004-9353036097db'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-01-21T04:15:14.202361+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-9006-6ebf-8003-e97da7cd6c10'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-9006-6ebf-8003-e97da7cd6c10'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-01-21T04:15:14.201363+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-8fff-6990-8002-a197dd96fac3'}}, tasks=(PregelTask(id='ce38a849-4d34-377b-2242-6f4ccc06626b', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-8fff-6990-8002-a197dd96fac3'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-21T04:15:14.197362+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}}, tasks=(PregelTask(id='2f0ec4cc-a6c1-22b9-e636-2fc7db54e0eb', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa3-630f-8004-3d0e6467770e'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-01-21T04:13:20.075444+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa1-6f55-8003-ea7b31594171'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4fa1-6f55-8003-ea7b31594171'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-01-21T04:13:20.074939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9f-6840-8002-9178c3e3e6bb'}}, tasks=(PregelTask(id='f27515d9-7afa-970d-b877-466b0292a670', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9f-6840-8002-9178c3e3e6bb'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-21T04:13:20.073939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}}, tasks=(PregelTask(id='e82fda0a-394d-6176-e2af-70dc2850705f', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a27-8001-d6728d8b5a90'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T04:13:20.071939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a26-8000-1efe343bc4a2'}}, tasks=(PregelTask(id='ae3dd7ce-701d-2b3a-21b7-3cdb6afcb5ee', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f9a-6a26-8000-1efe343bc4a2'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-21T04:13:20.071939+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f95-6bcb-bfff-9cf2ca67628d'}}, tasks=(PregelTask(id='b8fe4744-950f-f6d6-4c34-781456673fab', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67f8-4f95-6bcb-bfff-9cf2ca67628d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-21T04:13:20.069933+00:00', parent_config=None, tasks=(PregelTask(id='45bd3b51-b2a4-53fe-c6a1-8f311f7ec9f1', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# ### Modify State
# Let's start by starting a fresh thread and running to clean out history.

# %%
thread2 = {"configurable": {"thread_id": str(2)}}
graph.invoke({"count":0, "scratch":"hi"},thread2)
# Out:
# node1, count:0
# node2, count:1
# node1, count:2
# node2, count:3
# {'lnode': 'node_2', 'scratch': 'hi', 'count': 4}

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
states2 = []
for state in graph.get_state_history(thread2):
    states2.append(state.config)
    print(state.config, state.values['count'])
# Out:
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0088-6a12-8004-11b67348660b'}} 4
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0081-64b6-8003-bed087a994c3'}} 3
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffcc-6871-8002-ff091b374f95'}} 2
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc3-6c3f-8001-c2d442f2f7f4'}} 1
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc1-64f9-8000-9d8823ca3482'}} 0
# {'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffb9-6cf3-bfff-3785e7f6265d'}} 0

# %% [markdown]
# Start by grabbing a state.

# %%
save_state = graph.get_state(states2[-3])
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc3-6c3f-8001-c2d442f2f7f4'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T04:15:25.917907+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc1-64f9-8000-9d8823ca3482'}}, tasks=(PregelTask(id='d1b462e1-a5e2-e16c-4294-128aef4edaa7', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# Now modify the values. One subtle item to note: Recall when agent state was defined, `count` used `operator.add` to indicate that values are *added* to the current value. Here, `-3` will be added to the current count value rather than replace it.

# %%
save_state.values["count"] = -3
save_state.values["scratch"] = "hello"
save_state
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc3-6c3f-8001-c2d442f2f7f4'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T04:15:25.917907+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc1-64f9-8000-9d8823ca3482'}}, tasks=(PregelTask(id='d1b462e1-a5e2-e16c-4294-128aef4edaa7', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# Now update the state. This creates a new entry at the *top*, or *latest* entry in memory. This will become the current state.

# %%
graph.update_state(thread2,save_state.values)
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0f6802-c9cd-666c-8005-eff3d04b6995'}}

# %% [markdown]
# Current state is at the top. You can match the `thread_ts`.
# Notice the `parent_config`, `thread_ts` of the new node - it is the previous node.

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6802-c9cd-666c-8005-eff3d04b6995'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-01-21T04:18:01.320817+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0088-6a12-8004-11b67348660b'}}, tasks=(PregelTask(id='7e2c6a5f-dcc9-0151-25e3-81252db8f8fe', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result=None),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0088-6a12-8004-11b67348660b'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-01-21T04:15:25.998542+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0081-64b6-8003-bed087a994c3'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0081-64b6-8003-bed087a994c3'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-01-21T04:15:25.995538+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffcc-6871-8002-ff091b374f95'}}, tasks=(PregelTask(id='e1d1a63d-6edd-b07f-a060-ebdd2c402ec0', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())

# %% [markdown]
# ### Try again with `as_node`
# When writing using `update_state()`, you want to define to the graph logic which node should be assumed as the writer. What this does is allow th graph logic to find the node on the graph. After writing the values, the `next()` value is computed by travesing the graph using the new state. In this case, the state we have was written by `Node1`. The graph can then compute the next state as being `Node2`. Note that in some graphs, this may involve going through conditional edges!  Let's try this out.

# %%
graph.update_state(thread2,save_state.values, as_node="Node1")
# Out:
# {'configurable': {'thread_id': '2',
#   'checkpoint_ns': '',
#   'checkpoint_id': '1f0f6803-0f81-6913-8006-890c943e5c89'}}

# %%
for i, state in enumerate(graph.get_state_history(thread2)):
    if i >= 3:  #print latest 3
        break
    print(state, '\n')
# Out:
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-0f81-6913-8006-890c943e5c89'}}, metadata={'source': 'update', 'step': 6, 'parents': {}}, created_at='2026-01-21T04:18:08.629787+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6802-c9cd-666c-8005-eff3d04b6995'}}, tasks=(PregelTask(id='dc72a4f3-9b05-d75e-e35c-a86936d88429', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result=None),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6802-c9cd-666c-8005-eff3d04b6995'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-01-21T04:18:01.320817+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0088-6a12-8004-11b67348660b'}}, tasks=(PregelTask(id='7e2c6a5f-dcc9-0151-25e3-81252db8f8fe', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0088-6a12-8004-11b67348660b'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-01-21T04:15:25.998542+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0081-64b6-8003-bed087a994c3'}}, tasks=(), interrupts=())

# %% [markdown]
# `invoke` will run from the current state if not given a particular `thread_ts`. This is now the entry that was just added.

# %%
graph.invoke(None,thread2)
# Out:
# node2, count:-2
# node1, count:-1
# node2, count:0
# node1, count:1
# node2, count:2
# {'lnode': 'node_2', 'scratch': 'hello', 'count': 3}

# %% [markdown]
# Print out the state history, notice the `scratch` value change on the latest entries.

# %%
for state in graph.get_state_history(thread2):
    print(state,"\n")
# Out:
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 3}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43eb-66ee-800b-3d3ca15b2468'}}, metadata={'source': 'loop', 'step': 11, 'parents': {}}, created_at='2026-01-21T04:18:14.125745+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43e8-6e6c-800a-41fb3e62347a'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43e8-6e6c-800a-41fb3e62347a'}}, metadata={'source': 'loop', 'step': 10, 'parents': {}}, created_at='2026-01-21T04:18:14.124708+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43e4-6033-8009-1db23d1434ac'}}, tasks=(PregelTask(id='354666f5-79c3-250d-af22-f5a2c3a8e03d', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43e4-6033-8009-1db23d1434ac'}}, metadata={'source': 'loop', 'step': 9, 'parents': {}}, created_at='2026-01-21T04:18:14.122705+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43dd-6df0-8008-22963fa794b7'}}, tasks=(PregelTask(id='90dfb048-7cc6-9802-8668-b17db12bf6e9', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 0}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43dd-6df0-8008-22963fa794b7'}}, metadata={'source': 'loop', 'step': 8, 'parents': {}}, created_at='2026-01-21T04:18:14.120190+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43d8-6b8c-8007-a002ef7ed879'}}, tasks=(PregelTask(id='e8d873aa-7f4f-4419-d724-46ee62439fb4', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hello', 'count': -1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-43d8-6b8c-8007-a002ef7ed879'}}, metadata={'source': 'loop', 'step': 7, 'parents': {}}, created_at='2026-01-21T04:18:14.118081+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-0f81-6913-8006-890c943e5c89'}}, tasks=(PregelTask(id='ba05111e-7306-69e7-3e08-14f70257e8bd', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': -2}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6803-0f81-6913-8006-890c943e5c89'}}, metadata={'source': 'update', 'step': 6, 'parents': {}}, created_at='2026-01-21T04:18:08.629787+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6802-c9cd-666c-8005-eff3d04b6995'}}, tasks=(PregelTask(id='dc72a4f3-9b05-d75e-e35c-a86936d88429', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hello', 'count': 1}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f6802-c9cd-666c-8005-eff3d04b6995'}}, metadata={'source': 'update', 'step': 5, 'parents': {}}, created_at='2026-01-21T04:18:01.320817+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0088-6a12-8004-11b67348660b'}}, tasks=(PregelTask(id='7e2c6a5f-dcc9-0151-25e3-81252db8f8fe', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'scratch': 'hello', 'count': -3}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 4}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0088-6a12-8004-11b67348660b'}}, metadata={'source': 'loop', 'step': 4, 'parents': {}}, created_at='2026-01-21T04:15:25.998542+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0081-64b6-8003-bed087a994c3'}}, tasks=(), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 3}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fd-0081-64b6-8003-bed087a994c3'}}, metadata={'source': 'loop', 'step': 3, 'parents': {}}, created_at='2026-01-21T04:15:25.995538+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffcc-6871-8002-ff091b374f95'}}, tasks=(PregelTask(id='e1d1a63d-6edd-b07f-a060-ebdd2c402ec0', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_2', 'scratch': 'hi', 'count': 2}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffcc-6871-8002-ff091b374f95'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-01-21T04:15:25.921496+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc3-6c3f-8001-c2d442f2f7f4'}}, tasks=(PregelTask(id='670f808b-ca01-7678-bc5a-24a6aaaf949e', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'lnode': 'node_1', 'scratch': 'hi', 'count': 1}, next=('Node2',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc3-6c3f-8001-c2d442f2f7f4'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-01-21T04:15:25.917907+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc1-64f9-8000-9d8823ca3482'}}, tasks=(PregelTask(id='d1b462e1-a5e2-e16c-4294-128aef4edaa7', name='Node2', path=('__pregel_pull', 'Node2'), error=None, interrupts=(), state=None, result={'lnode': 'node_2', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'scratch': 'hi', 'count': 0}, next=('Node1',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffc1-64f9-8000-9d8823ca3482'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-01-21T04:15:25.916901+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffb9-6cf3-bfff-3785e7f6265d'}}, tasks=(PregelTask(id='082a8a3f-291d-a1aa-7615-2f6ce87b2f62', name='Node1', path=('__pregel_pull', 'Node1'), error=None, interrupts=(), state=None, result={'lnode': 'node_1', 'count': 1}),), interrupts=())
#
# StateSnapshot(values={'count': 0}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f0f67fc-ffb9-6cf3-bfff-3785e7f6265d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-01-21T04:15:25.913829+00:00', parent_config=None, tasks=(PregelTask(id='d2108a49-eca0-fba3-2047-b803c9817f02', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'count': 0, 'scratch': 'hi'}),), interrupts=())

# %% [markdown]
# Continue to experiment!
