# %% [markdown]
# # Lesson 6: Essay Writer

# %%
from dotenv import load_dotenv

_ = load_dotenv()

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict, Annotated, List
import operator
from langgraph.checkpoint.sqlite import SqliteSaver
from langchain_core.messages import AnyMessage, SystemMessage, HumanMessage, AIMessage, ChatMessage
import sqlite3

# Create a connection manually to keep it alive across notebook cells
conn = sqlite3.connect(":memory:", check_same_thread=False)
memory = SqliteSaver(conn)

# %%
class AgentState(TypedDict):
    task: str
    plan: str
    draft: str
    critique: str
    content: List[str]
    revision_number: int
    max_revisions: int

# %%
from langchain_openai import ChatOpenAI
model = ChatOpenAI(model="gpt-3.5-turbo", temperature=0)

# %%
PLAN_PROMPT = """You are an expert writer tasked with writing a high level outline of an essay. \
Write such an outline for the user provided topic. Give an outline of the essay along with any relevant notes \
or instructions for the sections."""

# %%
WRITER_PROMPT = """You are an essay assistant tasked with writing excellent 5-paragraph essays.\
Generate the best essay possible for the user's request and the initial outline. \
If the user provides critique, respond with a revised version of your previous attempts. \
Utilize all the information below as needed: 

------

{content}"""

# %%
REFLECTION_PROMPT = """You are a teacher grading an essay submission. \
Generate critique and recommendations for the user's submission. \
Provide detailed recommendations, including requests for length, depth, style, etc."""

# %%
RESEARCH_PLAN_PROMPT = """You are a researcher charged with providing information that can \
be used when writing the following essay. Generate a list of search queries that will gather \
any relevant information. Only generate 3 queries max."""

# %%
RESEARCH_CRITIQUE_PROMPT = """You are a researcher charged with providing information that can \
be used when making any requested revisions (as outlined below). \
Generate a list of search queries that will gather any relevant information. Only generate 3 queries max."""

# %%
from langchain_core.pydantic_v1 import BaseModel

class Queries(BaseModel):
    queries: List[str]

# %%
from tavily import TavilyClient
import os
tavily = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

# %%
def plan_node(state: AgentState):
    messages = [
        SystemMessage(content=PLAN_PROMPT), 
        HumanMessage(content=state['task'])
    ]
    response = model.invoke(messages)
    return {"plan": response.content}

# %%
def research_plan_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_PLAN_PROMPT),
        HumanMessage(content=state['task'])
    ])
    content = state.get('content', []) or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def generation_node(state: AgentState):
    content = "\n\n".join(state['content'] or [])
    user_message = HumanMessage(
        content=f"{state['task']}\n\nHere is my plan:\n\n{state['plan']}")
    messages = [
        SystemMessage(
            content=WRITER_PROMPT.format(content=content)
        ),
        user_message
        ]
    response = model.invoke(messages)
    return {
        "draft": response.content, 
        "revision_number": state.get("revision_number", 1) + 1
    }

# %%
def reflection_node(state: AgentState):
    messages = [
        SystemMessage(content=REFLECTION_PROMPT), 
        HumanMessage(content=state['draft'])
    ]
    response = model.invoke(messages)
    return {"critique": response.content}

# %%
def research_critique_node(state: AgentState):
    queries = model.with_structured_output(Queries).invoke([
        SystemMessage(content=RESEARCH_CRITIQUE_PROMPT),
        HumanMessage(content=state['critique'])
    ])
    content = state['content'] or []
    for q in queries.queries:
        response = tavily.search(query=q, max_results=2)
        for r in response['results']:
            content.append(r['content'])
    return {"content": content}

# %%
def should_continue(state):
    if state["revision_number"] > state["max_revisions"]:
        return END
    return "reflect"

# %%
builder = StateGraph(AgentState)

# %%
builder.add_node("planner", plan_node)
builder.add_node("generate", generation_node)
builder.add_node("reflect", reflection_node)
builder.add_node("research_plan", research_plan_node)
builder.add_node("research_critique", research_critique_node)

# %%
builder.set_entry_point("planner")

# %%
builder.add_conditional_edges(
    "generate", 
    should_continue, 
    {END: END, "reflect": "reflect"}
)

# %%
builder.add_edge("planner", "research_plan")
builder.add_edge("research_plan", "generate")

builder.add_edge("reflect", "research_critique")
builder.add_edge("research_critique", "generate")

# %%
graph = builder.compile(checkpointer=memory)

# %%
from IPython.display import Image, display

display(Image(graph.get_graph().draw_mermaid_png()))

# %%
thread = {"configurable": {"thread_id": "1"}}
for s in graph.stream({
    'task': "what is the difference between langchain and langsmith",
    "max_revisions": 2,
    "revision_number": 1,
}, thread):
    print(s)
# Out:
# {'planner': {'plan': 'I. Introduction\n    A. Brief overview of Langchain and Langsmith\n    B. Thesis statement: Exploring the differences between Langchain and Langsmith\n\nII. Langchain\n    A. Definition and explanation\n    B. Key features and characteristics\n    C. Use cases and applications\n    D. Advantages and disadvantages\n\nIII. Langsmith\n    A. Definition and explanation\n    B. Key features and characteristics\n    C. Use cases and applications\n    D. Advantages and disadvantages\n\nIV. Comparison between Langchain and Langsmith\n    A. Technical differences\n    B. Functional differences\n    C. Market adoption and popularity\n    D. Future prospects and trends\n\nV. Conclusion\n    A. Recap of main points\n    B. Final thoughts on the significance of understanding the differences between Langchain and Langsmith\n    C. Potential impact on the field of language technology\n\nNotes:\n- Ensure a clear and concise explanation of both Langchain and Langsmith.\n- Provide specific examples to illustrate the differences between the two technologies.\n- Use reliable sources to support the information presented in the essay.\n- Consider the target audience and adjust the level of technical detail accordingly.'}}
# {'research_plan': {'content': ['If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Additionally, if you’re working on **cross-platform model deployments** — say, running models on-prem and in the cloud simultaneously — Langsmith offers better orchestration and monitoring tools to handle the complexity. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', 'LangChain and LangSmith are two powerful tools developed by LangChain, a company focused on making it easier to build and deploy Large Language Model (LLM) applications. In this blog, we’ll delve into the differences between LangChain and LangSmith, their pros and cons, and when to use each one. LangSmith is a unified DevOps platform for developing, collaborating, testing, deploying, and monitoring LLM applications. 1. Comprehensive Platform: LangSmith offers a unified platform for managing all aspects of LLM development, making it ideal for large-scale, production-ready applications. 2. Debugging and Testing: LangSmith provides advanced debugging and testing tools, making it easier to identify and resolve issues in LLM applications. LangChain and LangSmith are two complementary tools that cater to different stages and requirements of LLM development. LangChain is ideal for early-stage prototyping and small-scale applications, while LangSmith is better suited for large-scale, production-ready applications that require advanced debugging, testing, and monitoring capabilities. ## Published in GoPenAI.', '[Skip to main content](https://docs.langchain.com/oss/python/langchain/overview#content-area). *   [Overview](https://docs.langchain.com/oss/python/langchain/overview). *   [Agents](https://docs.langchain.com/oss/python/langchain/agents). *   [Models](https://docs.langchain.com/oss/python/langchain/models). *   [Messages](https://docs.langchain.com/oss/python/langchain/messages). *   [Overview](https://docs.langchain.com/oss/python/langchain/middleware/overview). *   [Built-in middleware](https://docs.langchain.com/oss/python/langchain/middleware/built-in). *   [Model Context Protocol (MCP)](https://docs.langchain.com/oss/python/langchain/mcp). *   [LangSmith Studio](https://docs.langchain.com/oss/python/langchain/studio). *   [Agent Chat UI](https://docs.langchain.com/oss/python/langchain/ui). *   [Deployment](https://docs.langchain.com/oss/python/langchain/deploy). *   [Create an agent](https://docs.langchain.com/oss/python/langchain/overview#create-an-agent). *   [Core benefits](https://docs.langchain.com/oss/python/langchain/overview#core-benefits). LangChain is the easiest way to start building agents and applications powered by LLMs. With under 10 lines of code, you can connect to OpenAI, Anthropic, Google, and [more](https://docs.langchain.com/oss/python/integrations/providers/overview). [\u200b](https://docs.langchain.com/oss/python/langchain/overview#create-an-agent). [\u200b](https://docs.langchain.com/oss/python/langchain/overview#core-benefits). Learn more](https://docs.langchain.com/oss/python/langchain/models)[Easy to use, highly flexible agent ---------------------------------- LangChain’s agent abstraction is designed to be easy to get started with, letting you build a simple agent in under 10 li ...
# {'generate': {'draft': "**Essay:**\n\n**Exploring the Differences Between Langchain and Langsmith**\n\n**I. Introduction**\n\nLangchain and Langsmith are two powerful tools developed by LangChain, a company focused on making it easier to build and deploy Large Language Model (LLM) applications. While both tools cater to the development and deployment of LLM applications, they serve different purposes and offer distinct features. This essay aims to delve into the dissimilarities between Langchain and Langsmith to provide a comprehensive understanding of their functionalities and applications.\n\n**II. Langchain**\n\nLangchain is an open-source framework designed to simplify the creation of applications using large language models (LLMs). It is ideal for early-stage prototyping and small-scale applications. Key features of Langchain include an easy-to-use agent abstraction, built on top of LangGraph, allowing users to build simple agents with minimal code. Langchain is best suited for projects that require quick prototyping and experimentation with LLMs. However, its capabilities may be limited when it comes to managing large-scale, production-ready applications.\n\n**III. Langsmith**\n\nOn the other hand, Langsmith is a framework tailored to enhance and streamline the development of natural language processing (NLP) applications. It offers a unified DevOps platform for developing, collaborating, testing, deploying, and monitoring LLM applications. Langsmith provides advanced debugging and testing tools, making it easier to identify and resolve issues in complex AI systems in production. It is specifically designed for managing large-scale workflows with multiple moving parts, offering deep visibility and control over intricate AI systems.\n\n**IV. Comparison between Langchain and Langsmith**\n\n**A. Technical Differences:** Langchain focuses on simplifying the creation of applications using LLMs, while Langsmith emphasizes advanced debugging, testing, and monitoring capabilities for large-scale, production-ready applications.\n\n**B. Functional Differences:** Langchain is more suitable for early-stage prototyping and small-scale applications, whereas Langsmith is better equipped to handle complex AI pipelines with multiple models that require debugging and orchestrating.\n\n**C. Market Adoption and Popularity:** Langchain may be more popular among developers looking to quickly prototype LLM applications, while Langsmith is gaining traction among organizations that require deep visibility and control over their AI systems in production.\n\n**D. Future Prospects and Trends:** As the demand for sophisticated AI applications grows, both Langchain and Langsmith are likely to evolve to meet the changing needs of developers and organizations working with LLMs.\n\n**V. Conclusion**\n\nIn conclusion, understanding the differences between Langchain and Langsmith is crucial for developers and organizations working with large language models. While Langchain is ideal for quick prototyping and small-scale applications, Langsmith offers advanced debugging and monitoring tools for managing complex AI systems in production. By choosing the right tool based on the project's complexity, scalability needs, and level of control required, developers can effectively leverage the capabilities of LangChain's offerings in the field of language technology.\n\n**Revised Essay:**\n\nThe initial essay provided a comprehensive overview of the differences between Langchain and Langsmith, highlighting their key features, use cases, and advantages. If you have any specific areas you would like to focus on or any additional information you would like to include, please let me know for further revisions.", 'revision_number': 2}}
# {'reflect': {'critique': "**Critique:**\n\nThe essay provides a clear and structured comparison between Langchain and Langsmith, outlining their technical differences, functional distinctions, market adoption, and future prospects. The introduction effectively sets the stage for the discussion, and the conclusion succinctly summarizes the key points. The content is informative and well-organized, making it easy for readers to understand the contrasts between the two tools.\n\n**Recommendations:**\n\n1. **Depth and Analysis:** While the essay covers the basics of Langchain and Langsmith, consider delving deeper into specific features, functionalities, and use cases of each tool. Providing examples or case studies could help illustrate how Langchain and Langsmith are applied in real-world scenarios, enhancing the reader's understanding.\n\n2. **Comparison Details:** To enrich the comparison, consider elaborating on how Langchain and Langsmith handle specific challenges or scenarios differently. For instance, discuss how each tool addresses scalability, performance optimization, integration with other systems, or compatibility with different programming languages.\n\n3. **User Experience:** Include insights on the user experience of working with Langchain and Langsmith. Discuss aspects such as ease of use, learning curve, documentation quality, community support, and any unique advantages that make one tool more user-friendly or developer-friendly than the other.\n\n4. **Visual Aids:** Incorporating visual aids like diagrams, charts, or tables can help visualize the differences between Langchain and Langsmith effectively. Visual representations can enhance the reader's comprehension and make complex concepts easier to grasp.\n\n5. **Case Studies or Testimonials:** If possible, include case studies or testimonials from users who have experience with Langchain and Langsmith. Real-world examples can provide valuable insights into the practical benefits and challenges of using these tools in different contexts.\n\n6. **Revised Conclusion:** Consider expanding the conclusion to emphasize the significance of choosing the right tool based on specific project requirements. Highlight the impact of selecting the appropriate tool on project success, efficiency, and overall outcomes in the realm of language technology.\n\nBy incorporating these recommendations, you can enhance the depth, clarity, and engagement of your essay, providing readers with a more comprehensive understanding of the nuances between Langchain and Langsmith."}}
# {'research_critique': {'content': ['If you’re responsible for ensuring your AI models work in production, or you need to frequently debug and monitor your pipelines, Langsmith is your go-to tool. In short, while **Langchain** excels at managing and scaling model workflows, **Langsmith** is designed for those times when you need deep visibility and control over large, complex AI systems in production. But if you’re managing a **complex AI pipeline** with multiple models that need debugging and orchestrating, Langsmith’s capabilities become essential. If you’re debugging complex AI models or managing large-scale workflows with multiple moving parts, **Langsmith’s advanced debugging and orchestration features** will be indispensable. Additionally, if you’re working on **cross-platform model deployments** — say, running models on-prem and in the cloud simultaneously — Langsmith offers better orchestration and monitoring tools to handle the complexity. Choosing between **Langchain** and **Langsmith** boils down to understanding your project’s complexity, scalability needs, and the level of control you want over your AI models.', 'LangChain and LangSmith are two powerful tools developed by LangChain, a company focused on making it easier to build and deploy Large Language Model (LLM) applications. In this blog, we’ll delve into the differences between LangChain and LangSmith, their pros and cons, and when to use each one. LangSmith is a unified DevOps platform for developing, collaborating, testing, deploying, and monitoring LLM applications. 1. Comprehensive Platform: LangSmith offers a unified platform for managing all aspects of LLM development, making it ideal for large-scale, production-ready applications. 2. Debugging and Testing: LangSmith provides advanced debugging and testing tools, making it easier to identify and resolve issues in LLM applications. LangChain and LangSmith are two complementary tools that cater to different stages and requirements of LLM development. LangChain is ideal for early-stage prototyping and small-scale applications, while LangSmith is better suited for large-scale, production-ready applications that require advanced debugging, testing, and monitoring capabilities. ## Published in GoPenAI.', '[Skip to main content](https://docs.langchain.com/oss/python/langchain/overview#content-area). *   [Overview](https://docs.langchain.com/oss/python/langchain/overview). *   [Agents](https://docs.langchain.com/oss/python/langchain/agents). *   [Models](https://docs.langchain.com/oss/python/langchain/models). *   [Messages](https://docs.langchain.com/oss/python/langchain/messages). *   [Overview](https://docs.langchain.com/oss/python/langchain/middleware/overview). *   [Built-in middleware](https://docs.langchain.com/oss/python/langchain/middleware/built-in). *   [Model Context Protocol (MCP)](https://docs.langchain.com/oss/python/langchain/mcp). *   [LangSmith Studio](https://docs.langchain.com/oss/python/langchain/studio). *   [Agent Chat UI](https://docs.langchain.com/oss/python/langchain/ui). *   [Deployment](https://docs.langchain.com/oss/python/langchain/deploy). *   [Create an agent](https://docs.langchain.com/oss/python/langchain/overview#create-an-agent). *   [Core benefits](https://docs.langchain.com/oss/python/langchain/overview#core-benefits). LangChain is the easiest way to start building agents and applications powered by LLMs. With under 10 lines of code, you can connect to OpenAI, Anthropic, Google, and [more](https://docs.langchain.com/oss/python/integrations/providers/overview). [\u200b](https://docs.langchain.com/oss/python/langchain/overview#create-an-agent). [\u200b](https://docs.langchain.com/oss/python/langchain/overview#core-benefits). Learn more](https://docs.langchain.com/oss/python/langchain/models)[Easy to use, highly flexible agent ---------------------------------- LangChain’s agent abstraction is designed to be easy to get started with, letting you build a simple agent in under 1 ...
# {'generate': {'draft': "**Essay:**\n\n**I. Introduction**\n\nLangChain and LangSmith are two powerful tools developed by LangChain, a company focused on simplifying the creation and deployment of Large Language Model (LLM) applications. While both tools cater to the needs of AI developers, they serve distinct purposes in the development lifecycle. This essay aims to delve into the disparities between LangChain and LangSmith, shedding light on their unique features and applications.\n\n**II. LangChain**\n\nLangChain is an open-source framework designed to facilitate the creation of applications utilizing large language models. It provides a user-friendly platform for early-stage prototyping and small-scale applications. LangChain's key features include an easy-to-use agent abstraction, built on top of LangGraph, enabling developers to create simple agents with minimal code. However, LangChain requires users to define tools, prompt logic, and output parsers themselves, which can be a drawback for those seeking a more comprehensive solution.\n\n**III. LangSmith**\n\nIn contrast, LangSmith is a unified DevOps platform tailored for large-scale, production-ready applications that demand advanced debugging, testing, and monitoring capabilities. It offers a comprehensive platform for managing all aspects of LLM development, making it ideal for complex AI pipelines with multiple moving parts. LangSmith's advanced debugging and orchestration features provide deep visibility into agent behavior, aiding in the identification and resolution of issues efficiently.\n\n**IV. Comparison between LangChain and LangSmith**\n\nWhen comparing LangChain and LangSmith, technical and functional disparities become apparent. LangChain is best suited for early-stage prototyping and small-scale applications, offering simplicity and ease of use. On the other hand, LangSmith excels in managing complex AI pipelines, providing advanced debugging and testing tools for large-scale, production-ready applications. In terms of market adoption, LangSmith's capabilities for cross-platform model deployments and enhanced monitoring tools have garnered significant attention from developers working on intricate AI systems.\n\n**V. Conclusion**\n\nUnderstanding the differences between LangChain and LangSmith is crucial for developers navigating the realm of language technology. While LangChain simplifies the initial stages of application development, LangSmith caters to the demands of production-ready applications with its advanced debugging and monitoring features. By leveraging the strengths of each tool based on project complexity and scalability needs, developers can optimize their AI workflows effectively, ultimately shaping the future of language technology.\n\nIn conclusion, the significance of LangChain and LangSmith lies in their ability to streamline the development of LLM applications, offering tailored solutions for diverse stages of the development lifecycle. As the field of language technology continues to evolve, a nuanced understanding of these tools will be instrumental in driving innovation and progress in AI development.", 'revision_number': 3}}

# %% [markdown]
# ## Essay Writer Interface

# %%
import warnings
warnings.filterwarnings("ignore")

from helper import ewriter, writer_gui
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[40], line 4
#       1 import warnings
#       2 warnings.filterwarnings("ignore")
# ----> 4 from helper import ewriter, writer_gui
#
# ModuleNotFoundError: No module named 'helper'

# %%
MultiAgent = ewriter()
app = writer_gui(MultiAgent.graph)
app.launch()
